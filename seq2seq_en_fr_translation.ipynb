# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# ===============================================================================
#
# based on  [Sean Robertson](https://github.com/spro)'s tutorial
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ``` {.sourceCode .sh}
# [KEY: > input, = target, < output]
#
# > il est en train de peindre un tableau .
# = he is painting a picture .
# < he is painting a picture .
#
# > pourquoi ne pas essayer ce vin delicieux ?
# = why not try that delicious wine ?
# < why not try that delicious wine ?
#
# > elle n est pas poete mais romanciere .
# = she is not a poet but a novelist .
# < she not not a poet but a novelist .
#
# > vous etes trop maigre .
# = you re too skinny .
# < you re all alone .
# ```
#
# \... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the [sequence
# to sequence network](https://arxiv.org/abs/1409.3215), in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# To improve upon this model we\'ll use an [attention
# mechanism](https://arxiv.org/abs/1409.0473), which lets the decoder
# learn to focus over a specific range of the input sequence.

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# The English to French pairs are too big to include in the repository, so
# download to `data/eng-fra.txt` before continuing. The file is a tab
# separated list of translation pairs:
#
# ``` {.sourceCode .sh}
# I am cold.    J'ai froid.
# ```
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>Download the data from <a href="https://download.pytorch.org/tutorial/data.zip">here</a> and extract it to the current directory.</p>
# </div>

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/word-encoding.png)

# %% [markdown]
# We\'ll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called `Lang` which has word → index (`word2index`) and index → word
# (`index2word`) dictionaries, as well as a count of each word
# `word2count` which will be used to replace rare words later.

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z!?]+", r" ", s)
    return s.strip()

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. The files are all English → Other Language, so if we
# want to translate from Other Language → English I added the `reverse`
# flag to reverse the pairs.

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('data/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we\'ll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we\'re filtering to sentences that translate to
# the form \"I am\" or \"He is\" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -   Read text file and split into lines, split lines into pairs
# -   Normalize text, filter by length and content
# -   Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 11445 sentence pairs
# Counting words...
# Counted words:
# fra 4601
# eng 2991
# ['je suis tres mediocre en sport', 'i am very poor at sports']

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A [Sequence to Sequence network](https://arxiv.org/abs/1409.3215), or
# seq2seq network, or [Encoder Decoder
# network](https://arxiv.org/pdf/1406.1078v3.pdf), is a model consisting
# of two RNNs called the encoder and decoder. The encoder reads an input
# sequence and outputs a single vector, and the decoder reads that vector
# to produce an output sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence `Je ne suis pas le chat noir` →
# `I am not the black cat`. Most of the words in the input sentence have a
# direct translation in the output sentence, but are in slightly different
# orders, e.g. `chat noir` and `black cat`. Because of the `ne/pas`
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the \"meaning\" of the input sequence into a single
# vector --- a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# ===========
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/encoder-network.png)

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))
        output, hidden = self.gru(embedded)
        return output, hidden

# %% [markdown]
# The Decoder
# ===========
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ==============
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string `<SOS>`
# token, and the first hidden state is the context vector (the encoder\'s
# last hidden state).
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/decoder-network.png)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.embedding(input)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        return output, hidden

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we\'ll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# =================
#
# If only the context vector is passed between the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to \"focus\" on a different part of
# the encoder\'s outputs for every step of the decoder\'s own outputs.
# First we calculate a set of *attention weights*. These will be
# multiplied by the encoder output vectors to create a weighted
# combination. The result (called `attn_applied` in the code) should
# contain information about that specific part of the input sequence, and
# thus help the decoder choose the right output words.
#
# ![](https://i.imgur.com/1152PYf.png)
#
# Calculating the attention weights is done with another feed-forward
# layer `attn`, using the decoder\'s input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/attention-decoder-network.png)
#
# Bahdanau attention, also known as additive attention, is a commonly used
# attention mechanism in sequence-to-sequence models, particularly in
# neural machine translation tasks. It was introduced by Bahdanau et al.
# in their paper titled [Neural Machine Translation by Jointly Learning to
# Align and Translate](https://arxiv.org/pdf/1409.0473.pdf). This
# attention mechanism employs a learned alignment model to compute
# attention scores between the encoder and decoder hidden states. It
# utilizes a feed-forward neural network to calculate alignment scores.
#
# However, there are alternative attention mechanisms available, such as
# Luong attention, which computes attention scores by taking the dot
# product between the decoder hidden state and the encoder hidden states.
# It does not involve the non-linear transformation used in Bahdanau
# attention.
#
# In this tutorial, we will be using Bahdanau attention. However, it would
# be a valuable exercise to explore modifying the attention mechanism to
# use Luong attention.

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.Wa = nn.Linear(hidden_size, hidden_size)
        self.Ua = nn.Linear(hidden_size, hidden_size)
        self.Va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
        scores = scores.squeeze(2).unsqueeze(1)

        weights = F.softmax(scores, dim=-1)
        context = torch.bmm(weights, keys)

        return context, weights

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1):
        super(AttnDecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        attentions = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden, attn_weights = self.forward_step(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_outputs.append(decoder_output)
            attentions.append(attn_weights)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        attentions = torch.cat(attentions, dim=1)

        return decoder_outputs, decoder_hidden, attentions


    def forward_step(self, input, hidden, encoder_outputs):
        embedded =  self.dropout(self.embedding(input))

        query = hidden.permute(1, 0, 2)
        context, attn_weights = self.attention(query, encoder_outputs)
        input_gru = torch.cat((embedded, context), dim=2)

        output, hidden = self.gru(input_gru, hidden)
        output = self.out(output)

        return output, hidden, attn_weights

# %% [markdown]
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>There are other forms of attention that work around the lengthlimitation by using a relative position approach. Read about "localattention" in <a href="https://arxiv.org/abs/1508.04025">Effective Approaches to Attention-based Neural MachineTranslation</a>.</p>
# </div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

def get_dataloader(batch_size):
    input_lang, output_lang, pairs = prepareData('eng', 'fra', True)

    n = len(pairs)
    input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
    target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

    for idx, (inp, tgt) in enumerate(pairs):
        inp_ids = indexesFromSentence(input_lang, inp)
        tgt_ids = indexesFromSentence(output_lang, tgt)
        inp_ids.append(EOS_token)
        tgt_ids.append(EOS_token)
        input_ids[idx, :len(inp_ids)] = inp_ids
        target_ids[idx, :len(tgt_ids)] = tgt_ids

    train_data = TensorDataset(torch.LongTensor(input_ids).to(device),
                               torch.LongTensor(target_ids).to(device))

    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    return input_lang, output_lang, train_dataloader

# %% [markdown]
# Training the Model
# ==================
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the `<SOS>` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# \"Teacher forcing\" is the concept of using the real target outputs as
# each next input, instead of using the decoder\'s guess as the next
# input. Using teacher forcing causes it to converge faster but [when the
# trained network is exploited, it may exhibit
# instability](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf).
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation
# -intuitively it has learned to represent the output grammar and can
# \"pick up\" the meaning once the teacher tells it the first few words,
# but it has not properly learned how to create the sentence from the
# translation in the first place.
#
# Because of the freedom PyTorch\'s autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# `teacher_forcing_ratio` up to use more of it.

# %%
def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

    total_loss = 0
    for data in dataloader:
        input_tensor, target_tensor = data

        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

        loss = criterion(
            decoder_outputs.view(-1, decoder_outputs.size(-1)),
            target_tensor.view(-1)
        )
        loss.backward()

        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -   Start a timer
# -   Initialize optimizers and criterion
# -   Create set of training pairs
# -   Start empty losses array for plotting
#
# Then we call `train` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ================
#
# Plotting is done with matplotlib, using the array of loss values
# `plot_losses` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2) 
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.show()

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder\'s predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder\'s
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, n=10000):
    correct = 0
    total = 0
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words)

        # remove <EOS> token
        if output_sentence.replace('<EOS>', '').strip() == pair[1]:
            correct += 1
        total += 1


        print('<', output_sentence)
        print('')

    print(f'Accuracy: {correct / total * 100:.2f}%')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we\'ll get
# some reasonable results.
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>If you run this notebook you can train, interrupt the kernel,evaluate, and continue training later. Comment out the lines where theencoder and decoder are initialized and run <code>trainIters</code> again.</p>
# </div>

# %%
hidden_size = 128
batch_size = 32

input_lang, output_lang, train_dataloader = get_dataloader(batch_size)

encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

train(train_dataloader, encoder, decoder, 80, print_every=5, plot_every=5)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 11445 sentence pairs
# Counting words...
# Counted words:
# fra 4601
# eng 2991
# 1m 45s (- 26m 25s) (5 6%) 1.5389
# 3m 32s (- 24m 46s) (10 12%) 0.6883
# 5m 3s (- 21m 53s) (15 18%) 0.3554
# 6m 43s (- 20m 11s) (20 25%) 0.1957
# 9m 36s (- 21m 8s) (25 31%) 0.1208
# 12m 40s (- 21m 8s) (30 37%) 0.0833
# 14m 50s (- 19m 5s) (35 43%) 0.0644
# 16m 27s (- 16m 27s) (40 50%) 0.0528
# 18m 1s (- 14m 1s) (45 56%) 0.0454
# 19m 43s (- 11m 50s) (50 62%) 0.0404
# 21m 16s (- 9m 40s) (55 68%) 0.0375
# 23m 12s (- 7m 44s) (60 75%) 0.0343
# 24m 45s (- 5m 42s) (65 81%) 0.0327
# 26m 41s (- 3m 48s) (70 87%) 0.0316
# 28m 33s (- 1m 54s) (75 93%) 0.0305
# 30m 23s (- 0m 0s) (80 100%) 0.0291

# %% [markdown]
# Set dropout layers to `eval` mode

# %%
encoder.eval()
decoder.eval()
evaluateRandomly(encoder, decoder)
# Out:
# > tu es la seule personne qui peut le convaincre
# = you re the only person that can persuade him
# < you re the only person that can persuade him
#
# > elle s inquiete pour ses examens
# = she s worrying about her exams
# < she s worrying about her exams
#
# > je suis fortune
# = i m wealthy
# < i m wealthy
#
# > je m eloigne de la ville pour quelques jours
# = i m leaving town for a few days
# < i m leaving town for a few days
#
# > je suis content que la pluie se soit arretee
# = i m glad that the rain has stopped
# < i m glad that the rain has stopped
#
# > je suis sure que tom a ete implique
# = i m sure tom was involved
# < i m sure tom was involved
#
# > il est tres talentueux
# = he s very talented
# < he s very talented
#
# > je suis desole je ne vous ai pas reconnues
# = i m sorry i didn t recognize you
# < i m sorry i didn t recognize you
#
# > elle est inquiete de ta securite
# = she s worried about your safety
# < she s worried about your safety
#
# > tu n es pas autorise a penetrer ici
# = you re not allowed in here
# < you re not allowed in here
#
# > vous etes imprudentes
# = you re foolish
# < you re foolish
#
# > elles sont semblables
# = they re similar
# < they re similar to society
#
# > il est lyceen
# = he is a student at a high school
# < he is a student at tennis
#
# > vous etes paranoiaques
# = you re being paranoid
# < you re being paranoid
#
# > je passe la nuit chez mon ami
# = i m staying over at my friend s place
# < i m staying over at my friend s place at
#
# > elle n est pas du genre a se marier
# = she s not the marrying type
# < she s not the marrying type
#
# > vous etes trop polies
# = you re too polite
# < you re too polite
#
# > il commence a avoir les foies
# = he s getting cold feet
# < he s getting cold feet
#
# > vous etes plein de talent
# = you re very talented
# < you re very talented
#
# > vous etes precis
# = you re precise
# < you re precise
#
# > elles sont inutiles
# = they re useless
# < they re useless
#
# > il nage dans la piscine
# = he is swimming in the pool
# < he is swimming in the pool
#
# > je suis responsable des courses
# = i m in charge of shopping
# < i m in charge of shopping
#
# > tu es celui que j attendais
# = you re the one i ve been waiting for
# < you re the one i ve been waiting for
#
# > je ne suis pas medecin mais enseignant
# = i m not a doctor but a teacher
# < i am not a doctor but a teacher
#
# > je suis professeur
# = i am a professor
# < i am a teacher
#
# > je suis fier de le tenir pour ami
# = i m proud to have him as a friend
# < i m proud to have him as a friend
#
# > il est trop honnete pour dire un mensonge
# = he is too honest to tell a lie
# < he is too drunk to tell a lie
#
# > je suis depourvue d ambition
# = i m unambitious
# < i m unambitious
#
# > vous etes tres avise
# = you re very wise
# < you re very wise and stupid
#
# > il a des soucis
# = he is in trouble
# < he is in trouble
#
# > vous prechez des convaincues
# = you re preaching to the choir
# < you re preaching to the choir of biology
#
# > je m habitue a manger seul
# = i m getting used to eating alone
# < i m getting used to eating alone
#
# > nous derangeons
# = we re interfering
# < we re interfering
#
# > je vais aller chercher a manger
# = i m going to go get some food
# < i m going to go get some food
#
# > je vous invite
# = i m inviting you
# < i m inviting you
#
# > nous regrettons de ne pas pouvoir vous aider
# = we re sorry we can t help you
# < we re sorry we can t help you
#
# > il devient ramollo avec l age
# = he s getting soft in his old age
# < he s getting soft in his old age
#
# > tu es une sacree menteuse
# = you re such a liar
# < you re such a liar
#
# > la moisson s annonce bonne cette annee
# = we re expecting a good harvest this year
# < we re expecting a good harvest this year
#
# > je suis plus grand
# = i am taller
# < i am taller than strong
#
# > tu es negligente
# = you re careless
# < you re careless
#
# > tu t embrouilles
# = you re confused
# < you re confused
#
# > j ai hate de te revoir dimanche prochain
# = i am looking forward to seeing you next sunday
# < i am looking forward to seeing you next sunday
#
# > elles sont asiatiques
# = they re asian
# < they re asian asian
#
# > vous etes un grand malade
# = you are seriously ill
# < you are seriously ill
#
# > je suis heureuse pour vous deux
# = i m happy for you both
# < i m happy for you both
#
# > nous sommes hors de danger
# = we are out of danger
# < we are out of danger danger
#
# > elle tente de prouver l existence de fantomes
# = she is trying to prove the existence of ghosts
# < she is trying to prove the existence of ghosts
#
# > nous n avons pas encore fini de jouer
# = we re not done playing yet
# < we re not done playing yet
#
# > je compte devenir ingenieur
# = i am going to be an engineer
# < i am going to be an engineer in our team
#
# > elle se brosse les cheveux
# = she is brushing her hair
# < she is brushing her hair
#
# > je ne suis pas jalouse
# = i m not jealous
# < i m not jealous
#
# > je ne suis pas ton amie
# = i m not your friend
# < i m not your friend
#
# > elles sont toutes en securite
# = they re all safe
# < they re all safe here
#
# > ils ont le meme age
# = they are the same age
# < they are the same age as friend
#
# > tu es fort ingenieuse
# = you re very clever
# < you re very clever
#
# > je ne suis pas un expert
# = i m not an expert
# < i m not an expert now
#
# > je retourne en fac
# = i m going back to college
# < i m going back to college
#
# > je suis a la prison
# = i m at the prison
# < i m at the prison
#
# > vous vous embrouillez a nouveau non ?
# = you re confused again aren t you ?
# < you re confused again aren t you ?
#
# > vous etes givres !
# = you re nuts !
# < you re nuts !
#
# > je suis professeur d anglais
# = i am an english teacher
# < i am a teacher of english
#
# > tu ne vas pas le croire
# = you re not going to believe this
# < you re not going to believe this
#
# > je suis motivee
# = i m motivated
# < i m motivated
#
# > c est un adulte
# = he s a grown man
# < he s a grown man
#
# > notre point de vue est biaise
# = we re biased
# < we re biased
#
# > nous sommes a l arret
# = we re stalled
# < we re stalled
#
# > nous avons fini de repondre aux questions
# = we re done answering questions
# < we re done answering questions
#
# > il est borne
# = he is thick headed
# < he is thick headed
#
# > je ne suis pas sur de vouloir le faire
# = i m not sure i want to do this
# < i m not sure i want to do this
#
# > je suis en train de jouer avec ma chatte
# = i m playing with my cat
# < i m playing with my cat
#
# > je le fais pour lui
# = i m doing this for him
# < i m doing this for him
#
# > il a probablement tort
# = he s probably wrong
# < he s probably wrong
#
# > il ment comme un arracheur de dents
# = he is lying through his teeth
# < he is lying through his teeth
#
# > je ne suis pas invitee a des fetes
# = i m not invited to parties
# < i m not invited to parties
#
# > je vais demenager le mois prochain
# = i m going to move next month
# < i m going to move next month
#
# > je ne vais nulle part avec ma voiture
# = i m not driving anywhere
# < i m not driving anywhere
#
# > vous n etes pas seules
# = you re not alone
# < you re not alone
#
# > je suis certain qu il est heureux
# = i m sure that he s happy
# < i m sure that he s happy
#
# > il est plus fort que toi
# = he s stronger than you
# < he is stronger than you are
#
# > je suis content de ne pas etre tom
# = i m glad i m not tom
# < i m glad i m not tom
#
# > je suis fatigue de ce temps chaud
# = i m sick of this hot weather
# < i m sick of this hot weather
#
# > je suis prepare a mourir
# = i am ready to die
# < i am ready to die
#
# > vous dites toujours ca
# = you re always saying that
# < you re always saying that that
#
# > je suis beaucoup plus a l aise maintenant
# = i m a lot more comfortable now
# < i m a lot more comfortable now
#
# > je peux nager dans la riviere
# = i am allowed to swim in the river
# < i am allowed to swim in the river
#
# > nous sommes toujours prudents
# = we re always careful
# < we re always careful
#
# > vous etes tres occupee
# = you re very busy
# < you re very busy
#
# > il a environ votre age
# = he s about the same age as you are
# < he is about your age age
#
# > il marche en direction de la gare
# = he is walking towards the station
# < he is walking towards the station
#
# > je vais en ville
# = i m going downtown
# < i m going downtown
#
# > je suis beaucoup plus jeune que toi
# = i m much younger than you
# < i m much younger than you
#
# > c est vous qui vous vous etes emballe
# = you re the one that went crazy
# < you re the one that went crazy
#
# > nous coulons
# = we re sinking
# < we re sinking
#
# > je suis a court d argent
# = i am running short of money
# < i am running out of money
#
# > elle depend de son epoux
# = she s dependent on her husband
# < she s dependent on her husband
#
# > il est en bonne condition physique
# = he is in good physical condition
# < he s in good physical condition
#
# > tu es responsable de ce que tu as fait
# = you are responsible for what you have done
# < you are responsible for what you have done
#
# > elle a peur des chiens qui aboient
# = she is afraid of barking dogs
# < she is afraid of barking dogs
#
# > c est un esprit independant
# = she s an independent thinker
# < he s an independent thinker
#
# > je suis fier de mon frere
# = i m proud of my brother
# < i m proud of my brother
#
# > je ne fais que supposer
# = i m just guessing
# < i m just guessing
#
# > je n ai simplement pas tres faim
# = i m just not very hungry
# < i m just not very hungry yet
#
# > nous avons un probleme
# = we re having some problem
# < we re having some problem
#
# > je suis sur le point de quitter ici
# = i am about to leave here
# < i am about to leave here
#
# > je suis encore occupee
# = i m still busy
# < i m still busy
#
# > elle a peur des chiens qui aboient
# = she is afraid of barking dogs
# < she is afraid of barking dogs
#
# > vous etes fort effrontees
# = you re very forward
# < you re very forward to
#
# > vous etes bonnes
# = you re good
# < you re good
#
# > elle est inquiete de ta securite
# = she s worried about your safety
# < she s worried about your safety
#
# > je creve d envie d une boisson fraiche
# = i m dying for a cold drink
# < i m dying for a cold drink
#
# > je suis fier de moi
# = i m proud of myself
# < i m proud of myself
#
# > vous etes un bon client
# = you are a good customer
# < you are a good customer
#
# > je suis assez fatiguee
# = i m quite tired
# < i m quite tired tired
#
# > je ne suis pas en train de mentir
# = i m not lying
# < i m not lying
#
# > nous n aboutissons nulle part
# = we re getting nowhere
# < we re getting nowhere
#
# > je suis prete a te suivre
# = i am ready to follow you
# < i am ready to follow you
#
# > vous ne dormez pas suffisamment
# = you re not sleeping enough
# < you re not sleeping enough
#
# > il aime ce genre de musique
# = he is fond of this kind of music
# < he is fond of this kind of music
#
# > ils sont au dessous
# = they re downstairs
# < they re downstairs
#
# > je suis tres heureux de ton travail
# = i m very pleased with your work
# < i m very pleased with your work
#
# > je suis mariee et j ai deux fils
# = i am married and i have two sons
# < i am married and i have two sons
#
# > je suis sans enthousiasme
# = i m unenthusiastic
# < i m unenthusiastic
#
# > il est nouveau en ville
# = he s new in town
# < he s new in town
#
# > je suis malade
# = i m ill
# < i m sick
#
# > tu n es pas citadine si ?
# = you re not a city girl are you ?
# < you re not a city girl are you ?
#
# > vous etes probablement fatiguees
# = you re probably tired
# < you re probably tired
#
# > vous etes tres craintifs
# = you re very timid
# < you re very timid
#
# > t es plein de fric
# = you re loaded
# < you re loaded
#
# > il n est pas du tout brillant
# = he is by no means bright
# < he is by no means bright
#
# > je suis assez forte
# = i m strong enough
# < i m strong enough strong
#
# > je suis vanne
# = i m exhausted
# < i m exhausted
#
# > je suis au restaurant
# = i m at the restaurant
# < i m at the restaurant
#
# > vous etes trop jeunes pour voyager seules
# = you are too young to travel alone
# < you are too young to travel alone
#
# > elle donne a chaque enfant deux pommes
# = she s giving each child two apples
# < she s giving each child two apples
#
# > nous sommes desoles de ne pas pouvoir vous aider
# = we re sorry we can t help you
# < we re sorry we can t help you
#
# > je suis desolee de t ennuyer si souvent
# = i m sorry to bother you so often
# < i m sorry to bother you so often
#
# > je ne pratique pas la divination
# = i m not a psychic
# < i m not a psychic
#
# > il est en train de lire un livre
# = he is reading a book
# < he is reading a book
#
# > j ai legerement faim
# = i m slightly hungry
# < i m slightly hungry hungry
#
# > je suis ravi que vous ayez souleve ca
# = i m glad you brought that up
# < i m glad you brought that up
#
# > je ne suis pas paye pour faire cela
# = i m not paid to do that
# < i m not paid to do that
#
# > je suis desolee si c est une question idiote
# = i m sorry if this is a stupid question
# < i m sorry if this is a stupid question
#
# > vous etes le seul en qui j ai confiance
# = you re the only one i trust
# < you re the only one i trust
#
# > vous n etes pas rationnelles
# = you re not being rational
# < you re not being rational
#
# > nous n en avons plus en stock
# = we re out of stock
# < we re out of stock
#
# > vous etes trop bruyante
# = you re too loud
# < you too too loud
#
# > nous sommes des survivantes
# = we re survivors
# < we re survivors
#
# > quel imbecile vous etes !
# = you re such an idiot !
# < you re such an idiot i trained me
#
# > je vais aller rejoindre les bras de morphee
# = i am going to sleep
# < i am going to sleep
#
# > vous etes dure
# = you re tough
# < you re tough
#
# > je suis desolee si je vous ai derange
# = i m sorry if i disturbed you
# < i m sorry if i disturbed you
#
# > ce sont des employees a temps partiel
# = they re part time employees
# < they re part time employees
#
# > c est un gentleman
# = he s a gentleman
# < he s a gentleman
#
# > je suis aussi grand que mon pere
# = i m as tall as my father
# < i m as tall as my father
#
# > je suis affolee
# = i m frantic
# < i m frantic
#
# > t es bourre
# = you re smashed
# < you re smashed
#
# > ce n est pas un mauvais bougre
# = he s not a bad guy
# < he s not a bad guy
#
# > nous sommes de retour
# = we re back
# < we re back
#
# > je suis decu et en colere
# = i m disappointed and angry
# < i m disappointed and angry
#
# > vous ne saignez pas
# = you re not bleeding
# < you re not bleeding
#
# > je suis fatigue de tout
# = i m tired of everything
# < i m tired of all tired
#
# > ce n est pas un homme ordinaire
# = he is no ordinary man
# < he is no ordinary man
#
# > je suis a votre disposition
# = i m at your disposal
# < i m at your disposal
#
# > il est plus intelligent qu eux
# = he s brighter than they are
# < he s brighter than they are
#
# > je ne fais pas partie de leurs admirateurs
# = i m not a fan
# < i m not a fan
#
# > nous ne sommes pas tes ennemies
# = we re not your enemy
# < we re not your enemy
#
# > il est meilleur que moi en maths
# = he is better than me at math
# < he is better than me at math
#
# > il est pret a y aller
# = he s ready to go
# < he s ready to go
#
# > je vais etre a l exterieur aujourd hui
# = i m going to be out today
# < i m going to be out today
#
# > nous avons tous deux tort
# = we re both wrong
# < we re both wrong
#
# > c est une belle jeune fille
# = she s a fine young lady
# < she s a fine young lady
#
# > nous sommes condamnes
# = we re doomed
# < we re doomed
#
# > je ne vais pas mentir
# = i m not going to lie
# < i m not going to lie
#
# > il est deux fois plus lourd que sa femme
# = he is twice as heavy as his wife
# < he is twice as heavy as his wife
#
# > c est un pigiste
# = he s a freelance journalist
# < he s a freelance journalist
#
# > tu es deloyale
# = you re disloyal
# < you re disloyal
#
# > je ne suis pas completement naive
# = i m not completely naive
# < i m not completely naive
#
# > vous etes fort curieux
# = you re very curious
# < you re very curious
#
# > il embrasse tres bien
# = he s a great kisser
# < he s a great kisser
#
# > elle est une violoniste d un certain renom
# = she s a violinist of some renown
# < she s a violinist of some renown
#
# > tu es trop bruyante
# = you re too loud
# < you too much too loud
#
# > il s en fourre plein les fouilles
# = he s raking it in
# < he s raking it in
#
# > elles sont courageuses
# = they re brave
# < they re brave brave
#
# > je suis desolee au sujet de la nuit derniere
# = i m sorry about last night
# < i m sorry about last night
#
# > c est un gentleman
# = he is a gentleman
# < he s a gentleman
#
# > j ai honte car j ai agi stupidement
# = i m ashamed because i acted foolishly
# < i m ashamed because i acted foolishly
#
# > il ne voit pas d un il
# = he is blind in one eye
# < he is blind in one eye
#
# > tu nous fais perdre notre temps
# = you re wasting our time
# < you re wasting our time time watching time
#
# > je suis bourre
# = i m sloshed
# < i m plastered
#
# > il est ruse et manipulateur
# = he s cunning and manipulative
# < he s cunning and manipulative
#
# > il souffre d un mal de dents
# = he is suffering from toothache
# < he is suffering from toothache
#
# > tu es trop bruyant
# = you re too loud
# < you re too loud
#
# > c est une personne sympathique
# = he is a friendly person
# < he is a friendly person is me
#
# > nous ne sommes pas encore libres
# = we re not free yet
# < we re not free yet
#
# > je ne suis pas interesse par une relation
# = i m not interested in a relationship
# < i m not interested in a relationship
#
# > ils quittent le japon demain
# = they are leaving japan tomorrow
# < they are leaving japan tomorrow
#
# > je ne suis pas decouragee
# = i m not discouraged
# < i m not discouraged
#
# > vous etes fort elegants
# = you re very sophisticated
# < you re very stylish
#
# > vous ne saignez pas
# = you re not bleeding
# < you re not bleeding
#
# > tu es desormais une femme
# = you re a woman now
# < you re a woman now
#
# > j irai la voir demain
# = i m going to see her tomorrow
# < i m going to see her tomorrow
#
# > vous etes tres gentil tom
# = you re very kind tom
# < you re very kind tom
#
# > il a peur des chiens
# = he s afraid of dogs
# < he is afraid of dogs
#
# > vous en faites partie
# = you re part of this
# < you re part of this part
#
# > c est un garcon intelligent
# = he is an intelligent boy
# < he is an intelligent boy
#
# > vous etes celui qui a plante cet arbre
# = you re the one who planted that tree
# < you re the one who planted that tree
#
# > on va bien rigoler
# = we re gonna have a lot of fun
# < we re gonna have a lot of fun
#
# > je suis en premier
# = i m first
# < i m first in first
#
# > je perds patience avec toi
# = i am losing my patience with you
# < i am losing my patience with you
#
# > je me rejouis de vous avoir finalement rencontre
# = i m glad to finally meet you
# < i m glad to finally meet you
#
# > ce sont toutes des etudiantes de la fac
# = they are all college students
# < they are all college students
#
# > nous sommes touches
# = we re touched
# < we re strong
#
# > tu me fais marcher !
# = you re kidding !
# < you re kidding !
#
# > vous etes tous prets
# = you re all set
# < you re all set
#
# > elle est au travail n est ce pas ?
# = she s at work isn t she ?
# < she s at work isn t she ?
#
# > je suis heureux que tu l aies aime
# = i m glad you liked it
# < i m happy you liked it
#
# > j ai la tete qui me tourne
# = i m feeling dizzy
# < i m feeling dizzy
#
# > tu es snob
# = you re a snob
# < you re a snob
#
# > vous etes dure
# = you re tough
# < you re tough
#
# > tu n es pas millionnaire
# = you re not a millionaire
# < you re not a millionaire aren t a millionaire
#
# > vous etes incroyables
# = you re incredible
# < you re amazing
#
# > il est bien paye
# = he is well paid
# < he is well paid
#
# > j arrive tout de suite
# = i m coming at once
# < i m coming right away
#
# > tu es perdue
# = you re lost
# < you re lost
#
# > je ne suis pas utile ici
# = i m unnecessary here
# < i m unnecessary here
#
# > il a peur de me parler
# = he s scared to talk to me
# < he s scared to talk to me
#
# > tu es chanceux d avoir un travail
# = you re lucky that you have a job
# < you re lucky that you have a job
#
# > je suis un nouvel etudiant
# = i am a new student
# < i m a new student now
#
# > elle est vraiment une fille ravissante
# = she s a real hottie
# < she s a real hottie
#
# > je suis fauche
# = i m broke
# < i m broke
#
# > tu es un etre mauvais
# = you are a bad person
# < you are a bad person
#
# > je vous suis profondement reconnaissante pour votre gentillesse
# = i am deeply grateful to you for your kindness
# < i am deeply grateful to you for your kindness
#
# > nous ne sommes pas surs
# = we re not sure
# < we re not sure
#
# > je ne suis pas si preoccupee
# = i m not that worried
# < i m not that worried
#
# > je ne suis vraiment pas interessee par l histoire
# = i m really not interested in history
# < i m really not interested in history
#
# > je suis stricte
# = i m strict
# < i m strict
#
# > nous ne sommes pas mariees
# = we re not married
# < we re not married
#
# > nous sommes obeissants
# = we re obedient
# < we re obedient
#
# > elle est hyperactive
# = she s hyperactive
# < she s hyperactive
#
# > il ne travaille pas beaucoup en ce moment
# = he s not working much at the moment
# < he s not working much at the moment
#
# > je suis en train de conduire
# = i m driving
# < i m driving
#
# > c est toi la professeur
# = you re the teacher
# < you re the teacher
#
# > je suis sur que tu vas reussir
# = i m sure that you ll succeed
# < i m sure that you ll succeed
#
# > il commence a avoir les foies
# = he s getting cold feet
# < he s getting cold feet
#
# > c est un japonais typique
# = he s a typical japanese man
# < he s a typical japanese man
#
# > vous etes productifs
# = you re productive
# < you re productive
#
# > je suis presque prete
# = i am almost ready
# < i am almost ready
#
# > vous n etes pas normale
# = you re not normal
# < you re not normal
#
# > tu es tellement impatiente
# = you re so impatient
# < you re so impatient
#
# > il n est pas tres bon en mathematiques
# = he is not very good at mathematics
# < he is not very good at mathematics
#
# > elle est sortie faire les magasins pour des chaussures
# = she s out shopping for shoes
# < she s out shopping for shoes
#
# > je suis heureux de t avoir invitee
# = i m glad i invited you
# < i m glad i invited you
#
# > je me meurs
# = i m dying
# < i m dying
#
# > vous n etes pas encore adolescent
# = you re not a teenager yet
# < you re not a teenager yet
#
# > sur ce point tu as raison
# = you re right about that one
# < you re right about that one you ll
#
# > c est mon partenaire
# = he s my partner
# < he s my partner
#
# > je vais devoir me teindre les cheveux
# = i m going to have to dye my hair
# < i m going to have to dye my hair
#
# > sans vous je ne suis rien
# = i m nothing without you
# < i m nothing without you
#
# > vous n etes pas seule
# = you re not alone
# < you re not alone anymore
#
# > ils travaillent tous les deux a l animalerie
# = they are both working at the pet store
# < they are both working at the pet store
#
# > il souffre
# = he s in pain
# < he is suffering suffering from england
#
# > je suis desole de vous ennuyer si souvent
# = i m sorry to bother you so often
# < i m sorry to bother you so often
#
# > tu es si gentil !
# = you re so sweet
# < you re so sweet
#
# > il est comme un pere pour moi
# = he is like a father to me
# < he is like a father to me
#
# > je suis impatient de voir ton pere
# = i m looking forward to seeing your father
# < i m looking forward to seeing your father your father
#
# > elle chante les dernieres chansons populaires
# = she is singing the latest popular songs
# < she is singing the latest popular songs
#
# > tu es negligente
# = you re careless
# < you re careless
#
# > tu es le seul qui puisse m aider
# = you are the only one who can help me
# < you are the only one who can help me
#
# > ils sont dans la douche
# = they re in the shower
# < they re in the shower
#
# > il est borgne
# = he is blind in one eye
# < he is blind in one eye
#
# > vous n etes pas malades
# = you re not sick
# < you re not sick
#
# > je suis indisponible
# = i m not available
# < i m not available
#
# > tu es astucieuse
# = you re crafty
# < you re crafty
#
# > tu es tres flexible
# = you re very flexible
# < you re very flexible
#
# > je suis sur que nous pouvons resoudre cela
# = i m sure we can work this out
# < i m sure we can work this out
#
# > nous sommes toutes etudiantes
# = we re all students
# < we re all students
#
# > tu es odieux
# = you re obnoxious
# < you re obnoxious
#
# > je vieillis
# = i m getting old
# < i m getting better bad cold
#
# > je suis deja marie
# = i m already married
# < i m already married
#
# > je ne suis pas assez bon pour toi
# = i m not good enough for you
# < i m not good enough for you
#
# > vous n interrompez rien
# = you re not interrupting anything
# < you re not interrupting anything
#
# > je ne m y rends pas
# = i m not going
# < i m not going it
#
# > je suis completement confus
# = i am totally confused
# < i am totally confused with the subject
#
# > je suis puissant
# = i m powerful
# < i m powerful
#
# > je suis contente que ca vous rende heureuse
# = i m glad that makes you happy
# < i m glad that makes you happy
#
# > je la rends
# = i m giving it back
# < i m giving it back
#
# > je crains les animaux sauvages
# = i m afraid of wild animals
# < i m afraid of wild animals
#
# > nous ne sommes pas des etrangers
# = we re not strangers
# < we re not strangers
#
# > ils ne sont toujours pas en securite
# = they re still not safe
# < they re still not safe
#
# > il est casse couilles avec moi
# = he is giving me a hard time
# < he is giving me a hard time
#
# > vous etes tires d affaire
# = you re off the hook
# < you re off the hook
#
# > vous etes plutot bonne
# = you re pretty good
# < you re pretty good
#
# > j apprends un peu d anglais
# = i am learning a little english
# < i m learning a little english
#
# > je suis celui qui paye toutes les factures
# = i m the one that pays all the bills
# < i m the one that pays all the bills
#
# > elle est completement sourde de l oreille gauche
# = she is completely deaf in her left ear
# < she is completely deaf in her left ear
#
# > elles se lavent les mains
# = they re washing their hands
# < they re washing their hands book
#
# > je ne trouve pas les mots
# = i m at a loss for words
# < i m at a loss for words
#
# > je suis a court de munitions
# = i m out of ammo
# < i m out of ammo
#
# > je suis votre et vous etes miens
# = i am yours and you are mine
# < i am yours and you are mine
#
# > vous etes si belle dans cette robe !
# = you re so beautiful in that dress
# < you re so beautiful in that dress
#
# > j ai raison
# = i am right
# < i m right
#
# > nous sommes un peu occupes ici
# = we re a little busy here
# < we re a little busy here
#
# > vous n etes pas tres amusantes
# = you re not very funny
# < you re not very funny
#
# > nous sommes depourvues de prejuges
# = we re unprejudiced
# < we re unprejudiced
#
# > nous sommes bourres
# = we re plastered
# < we re smashed
#
# > tu es autoritaire non ?
# = you re being bossy aren t you ?
# < you re being bossy aren t you ?
#
# > je suis desolee de vous ennuyer si souvent
# = i m sorry to bother you so often
# < i m sorry to bother you so often
#
# > je m occupe de mon grand pere
# = i m taking care of my grandfather
# < i m taking care of my grandfather
#
# > je reste pour quelques autres semaines
# = i am staying for another few weeks
# < i am staying for another few weeks
#
# > vous gagnez
# = you re winning
# < you re winning winning
#
# > ils sont juste derriere moi
# = they re right behind me
# < they re right behind me
#
# > je suis pret pour partir
# = i m ready to go
# < i m ready for go
#
# > je suis heureux que vous soyez la
# = i m happy you re here
# < i m happy you re here
#
# > nous nous dirigeons dans la bonne direction
# = we re headed in the right direction
# < we re headed in the right direction
#
# > elle est tres mignonne
# = she is very pretty
# < she is very pretty pretty
#
# > il est un peu jaloux
# = he s a bit jealous
# < he s a bit jealous but a bit jealous
#
# > tu es sur le chemin de la reussite
# = you re on the path of success
# < you re on the path of success
#
# > il est trop jeune pour boire
# = he s too young to drink
# < he s too young to drink
#
# > j en ai assez des conferences ces temps ci
# = i m sick of conferences these days
# < i m sick of conferences these days
#
# > vous etes mon ennemi
# = you re my enemy
# < you re my enemy
#
# > il est en train de vous regarder
# = he s looking at you
# < he s looking at you
#
# > ils sont decedes
# = they re dead
# < they re dead drunk
#
# > il n est pas americain
# = he isn t an american
# < he isn t an american
#
# > nous n en avons pas fini
# = we re not done
# < we re not done yet
#
# > il travaille dans le domaine de la biologie
# = he is working in the field of biology
# < he is working in the field of biology
#
# > vous etes plus grand qu elle
# = you are taller than she is
# < you are taller than she is
#
# > je suis canadien moi aussi
# = i m canadian too
# < i m canadian too as i am
#
# > ils vont faire les courses
# = they are going shopping
# < they are going shopping
#
# > il n est pas aussi age que mon frere
# = he s not as old as my brother
# < he s not as old as my brother
#
# > je ne vais pas abandonner maintenant
# = i m not quitting now
# < i m not quitting now
#
# > nous prenons le controle
# = we re taking over
# < we re taking over
#
# > il ne craint pas du tout les serpents
# = he s not at all afraid of snakes
# < he s not at all afraid of snakes
#
# > vous etes maigrichonne
# = you re skinny
# < you re skinny
#
# > je sais skier
# = i m able to ski
# < i m able to ski myself
#
# > vous etes la seule qui puisse m aider
# = you are the only one who can help me
# < you are the only one who can help me
#
# > ils sont en colere apres toi
# = they re mad at you
# < they re mad at you
#
# > je crains que nous ayons un probleme
# = i m afraid we have a problem
# < i m afraid we have a problem
#
# > je suis depourvue d idees
# = i m all out of ideas
# < i m all out of ideas
#
# > nous contribuons
# = we re contributing
# < we re contributing
#
# > je ne suis pas concerne par cette affaire
# = i am not concerned with this affair
# < i am not concerned with this affair
#
# > vous etes bons
# = you are good
# < you are good
#
# > je ne suis pas grand
# = i m not tall
# < i m not tall
#
# > nous avons aujourd hui un emploi du temps charge
# = we re on a tight schedule today
# < we re on a tight schedule today
#
# > je suis consciencieuse
# = i m thorough
# < i m thorough
#
# > t es bourre
# = you re smashed
# < you re smashed
#
# > vous etes tres peureuse
# = you re very timid
# < you re very timid
#
# > vous etes toujours en desaccord avec votre patron
# = you re always disagreeing with your boss
# < you re always disagreeing with your boss
#
# > nous n aboutissons nulle part
# = we re getting nowhere
# < we re getting nowhere
#
# > je ne suis absolument pas surpris
# = i am not in the least surprised
# < i am not in the least surprised
#
# > elle est bien plus intelligente qu elle ne parait
# = she s a lot smarter than she looks
# < she s a lot smarter than she looks
#
# > vous etes toutes a moi
# = you re all mine
# < you re all mine
#
# > je suis serieuse
# = i m not bluffing
# < i m not bluffing
#
# > je crains que ce soit impossible
# = i m afraid that s impossible
# < i m afraid that s impossible
#
# > je suis heureux que tom fut a mes cotes
# = i m glad tom was there with me
# < i m glad tom was there with me
#
# > c est un expert a la fronde
# = he s an expert with a slingshot
# < he s an expert with a slingshot
#
# > je suis plus vieux que lui
# = i am older than him
# < i am older than him
#
# > desole mais il n est pas a la maison
# = i m sorry but he isn t home
# < i m sorry but he isn t home
#
# > je suis fatigue maintenant
# = i m tired now
# < i m tired now now
#
# > nous avons rendez vous a midi
# = we are to meet at noon
# < we are to meet at noon
#
# > tu es la seule a pouvoir m aider
# = you re the only one who can help me
# < you re the only one who can help me
#
# > tu es encore jeune
# = you re still young
# < you re still young to understand
#
# > tu es incorrigible
# = you are hopeless
# < you are very incorrigible
#
# > vous n etes pas une sainte
# = you re no saint
# < you re no saint
#
# > tu es endurant
# = you re resilient
# < you re resilient
#
# > tu es fort sceptique
# = you re very skeptical
# < you re very skeptical teacher
#
# > tu es un etre mauvais
# = you are a bad person
# < you are a bad person
#
# > elle creuse sa propre tombe
# = she s digging her own grave
# < she s digging her own grave
#
# > je suis desole je me suis trompe de numero
# = i m sorry i dialed the wrong number
# < i m sorry i dialed the wrong number
#
# > vous n etes pas tres bonnes
# = you re not very good
# < you re not very good at this
#
# > il aime l aventure
# = he is fond of adventure
# < he is fond of adventure adventure against me
#
# > c est vous qui m avez forme
# = you re the one who trained me
# < you re the one who trained me
#
# > il est devant nous en mathematiques
# = he is ahead of us in mathematics
# < he is ahead of us in mathematics
#
# > vous n etes pas invite
# = you aren t invited
# < you aren t invited
#
# > je me demande si je l aime
# = i m wondering if i love her
# < i m wondering if i love her
#
# > ils vont commettre des erreurs
# = they re going to make mistakes
# < they re going to make mistakes
#
# > tu es un peu gras
# = you are a bit fat
# < you are a bit fat
#
# > je ne suis pas triste
# = i m not sad
# < i m not sad
#
# > elle est assise sur le banc
# = she s sitting on the bench
# < she s sitting on the bench
#
# > maintenant j ai des ennuis
# = i m in trouble now
# < i m in trouble now
#
# > je n en suis pas entierement sur
# = i m not entirely sure
# < i m not entirely sure
#
# > je ne suis pas endormi
# = i m not asleep
# < i m not sleepy
#
# > je ne suis pas en service aujourd hui
# = i am off today
# < i am off today
#
# > je suis rationnel
# = i m rational
# < i m rational
#
# > je suis content de ne pas avoir votre travail
# = i m glad i don t have your job
# < i m glad i don t have your job
#
# > elles sont sorties faire les magasins
# = they are out shopping
# < they are out shopping
#
# > vous etes vraiment geniale
# = you re really awesome
# < you re really upset
#
# > vous etes tres courageuse
# = you re very brave
# < you re very brave
#
# > ils sont en danger
# = they re in danger
# < they in danger in danger
#
# > je suis en train de me noyer
# = i m drowning
# < i m drowning
#
# > j ai raison
# = i m correct
# < i m right
#
# > elle porte un chapeau
# = she is wearing a hat
# < she is wearing a hat
#
# > c est mon frere aine
# = he s my older brother
# < he s my older brother s house
#
# > c est un heros inconnu
# = he is an unsung hero
# < he is an unsung hero
#
# > vous etes le chef
# = you re the boss
# < you re the leader
#
# > je suis ton meilleur ami
# = i m your best friend
# < i m your best friend
#
# > il n est pas a l interieur
# = he s not in
# < he s not in
#
# > je suis fou de toi
# = i m crazy about you
# < i m crazy about you
#
# > je suis coincee dans un embouteillage
# = i m stuck in a traffic jam
# < i m stuck in a traffic jam
#
# > tu es fort sage
# = you re very wise
# < you re very wise
#
# > je suis un vendeur
# = i m a salesperson
# < i m a salesperson
#
# > vous n etes pas grosse
# = you re not fat
# < you re not fat
#
# > je compte devenir ingenieur
# = i am going to be an engineer
# < i am going to be an engineer in our team
#
# > c est un etudiant paresseux
# = he is a lazy student
# < he is a lazy student
#
# > je ne suis pas tout a fait surpris
# = i m not exactly surprised
# < i m not exactly surprised
#
# > tu reagis de maniere excessive
# = you re overreacting
# < you re overreacting
#
# > tu es fort bonne
# = you re very good
# < you re very good
#
# > je suis fiere de vous tous
# = i m proud of you all
# < i m proud of you all
#
# > tu n es pas occupe maintenant si ?
# = you aren t busy now are you ?
# < you aren t busy now are you ?
#
# > c est toi le professeur
# = you re the teacher
# < you re the teacher
#
# > je suis coince dans un embouteillage
# = i m stuck in a traffic jam
# < i m stuck in a traffic jam
#
# > je porte mon maillot de bain sous mes vetements
# = i m wearing my swimsuit under my clothes
# < i m wearing my swimsuit under my clothes
#
# > c est une vraie concierge
# = she s a real gossip
# < she s a real gossip
#
# > je suis aussi grand que mon pere
# = i m as tall as my father
# < i m as tall as my father
#
# > je crains que tu t egares
# = i am afraid that you will get lost
# < i am afraid that you will get lost
#
# > il est sur le point de partir pour londres
# = he is about to leave for london
# < he is about to leave for london
#
# > il se trouve juste derriere vous
# = he s right behind you
# < he s right behind you
#
# > je souffre de vertige
# = i m afraid of heights
# < i m afraid of heights
#
# > tu es maline
# = you re clever
# < you re clever
#
# > j essaie quelque chose de nouveau
# = i m trying something new
# < i m trying something new
#
# > ce ne sont pas mes regles
# = they re not my rules
# < they re not my rules
#
# > c est une autorite en matiere d humanites
# = he is an authority on the humanities
# < he is an authority on the humanities
#
# > nous sommes tous ensemble a l instant
# = we re all together right now
# < we re all together right now
#
# > il est motive pour reussir
# = he is eager to succeed
# < he is eager to succeed for london
#
# > je suis de shizuoka
# = i am from shizuoka
# < i am from shizuoka
#
# > je suis contente que ca vous rende heureuses
# = i m glad that makes you happy
# < i m glad that makes you happy
#
# > on m utilise
# = i m being used
# < i m being used to me
#
# > ils sont tous ici
# = they re all here
# < they re all here
#
# > c est un ecrivain de talent
# = he s a talented writer
# < he s a talented writer
#
# > je suis ravie de vous voir
# = i m delighted to see you
# < i m glad to see you
#
# > tu es en train de mentir
# = you are lying
# < you are lying
#
# > tu es incroyablement naif
# = you are unbelievably naive
# < you are unbelievably naive
#
# > j en suis presque sur
# = i m almost sure of it
# < i m almost sure of sure
#
# > j attends le dejeuner
# = i m waiting for lunch
# < i m waiting for lunch to drink
#
# > je suis heureux parce que vous etes ici
# = i m happy because you re here
# < i m happy because you re here
#
# > je me brosse les dents
# = i am brushing my teeth
# < i am brushing my teeth
#
# > il est en colere apres toi
# = he is angry with you
# < he is angry with you
#
# > elles sont a tes trousses
# = they re out to get you
# < they re out to get you
#
# > nous sommes prets desormais
# = we re ready now
# < we re ready now
#
# > tu as tort
# = you are wrong
# < you are wrong
#
# > tu n ecoutes pas ce que je dis
# = you aren t listening to what i m saying
# < you aren t listening to what i m saying this
#
# > il est encore en vie
# = he s still alive
# < he s still alive
#
# > ils nous regardent tous
# = they re all watching us
# < they re all watching us all watching us
#
# > vous etes plus grand qu elle
# = you are taller than she is
# < you are taller than she is
#
# > elle est en colere apres vous
# = she is mad at you
# < she is mad at you
#
# > vous n etes pas satisfait si ?
# = you re not satisfied are you ?
# < you re not satisfied are you ?
#
# > c est un vieil ami a moi
# = he is an old friend of mine
# < he is an old friend of mine
#
# > tu es le plus grand
# = you are tallest
# < you are tallest boy
#
# > nous allons beaucoup nous amuser
# = we re going to have so much fun
# < we re going to have so much fun
#
# > elle vit au milieu de nulle part
# = she is living in the middle of nowhere
# < she is living in the middle of nowhere
#
# > je suis nul en langues
# = i m terrible at languages
# < i m terrible at languages
#
# > j ai bien peur que non
# = i m afraid not
# < i m afraid not looking
#
# > je suis en route pour retourner en ville
# = i m headed back into town
# < i m headed back into town
#
# > vous etes si gentil !
# = you re so sweet
# < you re so sweet
#
# > il porte ses livres sous son bras
# = he is holding his books under his arm
# < he is holding his books under his arm
#
# > vous etes supposee ne pas fumer a l ecole
# = you are not supposed to smoke at school
# < you are not supposed to smoke at school
#
# > il a l habitude de travailler dur
# = he is accustomed to hard work
# < he is accustomed to working hard
#
# > je n ai simplement pas tres faim
# = i m just not very hungry
# < i m just not very hungry yet
#
# > tu es completement ignorant
# = you re totally ignorant
# < you re totally ignorant
#
# > je ne suis pas encore prete
# = i am not ready yet
# < i m not ready yet
#
# > je mange ici
# = i m eating here
# < i am eating here
#
# > tu es fort avise
# = you re very wise
# < you re very wise
#
# > je suis desole mon pere est dehors
# = i m sorry my father is out
# < i m sorry my father is out
#
# > je vais vous donner une lecon
# = i m going to teach you a lesson
# < i m going to teach you a lesson
#
# > je ne suis plus ainsi
# = i m not like that anymore
# < i m not like that anymore
#
# > je prends des vacances a la plage
# = i am taking a holiday at the beach
# < i am taking a holiday at the beach
#
# > ils ne sont pas si mauvais
# = they re not so bad
# < they re not so bad bad
#
# > elle est trop jeune pour connaitre la verite
# = she is too young to know the truth
# < she is too young to know the truth
#
# > j en ai assez d entendre ca
# = i am tired of hearing that
# < i m sick of hearing that
#
# > ils sont asiatiques
# = they re asian
# < they re asian
#
# > vous etes bavardes
# = you re talkative
# < you re talkative
#
# > je ne suis pas de garde demain
# = i am off duty tomorrow
# < i am not on call tomorrow
#
# > j ai confiance
# = i m confident
# < i m confident
#
# > je suis sien et elle est mienne
# = i am hers and she is mine
# < i am hers and she is mine
#
# > vous analysez trop
# = you re over analyzing
# < you re over analyzing for too
#
# > je suis tellement gene que je veux mourir
# = i m so embarrassed i want to die
# < i m so embarrassed i want to die
#
# > elle est enceinte
# = she s pregnant
# < she s pregnant
#
# > vous etes stupides de vous fier a lui
# = you re stupid to trust him
# < you re stupid to trust him
#
# > il se plaint toujours de quelque chose
# = he s always complaining about something
# < he s always complaining about something
#
# > je suis finlandais mais je parle aussi le suedois
# = i am finnish but i speak also swedish
# < i am finnish but i speak also swedish
#
# > ils sont chanteurs
# = they are singers
# < they are singers there
#
# > tu es tres gentille
# = you re very nice
# < you re very nice
#
# > elle est inconsciente
# = she is unconscious
# < she is unconscious
#
# > nous n avons pas encore tres faim
# = we aren t very hungry yet
# < we aren t very hungry yet
#
# > je me porte bien
# = i m okay
# < i m well well well
#
# > il est l ami de tout le monde
# = he s everybody s friend
# < he s everybody s friend
#
# > tu fais aller ca trop loin
# = you re carrying this too far
# < you re carrying this too far
#
# > vous etes une sale menteuse !
# = you re a filthy liar !
# < you re a filthy liar !
#
# > je suis heureuse que tu aies rencontre tom
# = i m glad you met tom
# < i m glad you met tom
#
# > tu es tres ouvert
# = you re very open
# < you re very open
#
# > je ne vais pas nettoyer ca
# = i m not cleaning that up
# < i m not cleaning that up got that
#
# > je suis mecontente
# = i m unhappy
# < i m unhappy
#
# > tu es tres observateur
# = you re very observant
# < you re very observant
#
# > c est toi la prof
# = you re the teacher
# < you re the teacher
#
# > il a peur de mourir
# = he is afraid that he will die
# < he is afraid that he will die
#
# > nous ne sommes pas habillees
# = we re not dressed
# < we re not dressed
#
# > vous etes notre millionieme client
# = you are our one millionth customer
# < you are our one millionth customer millionth customer
#
# > nous n avons plus de vin
# = we re out of wine
# < we re out of wine
#
# > ils nettoient la plage
# = they re cleaning the beach
# < they re cleaning the beach
#
# > tu n es pas si folle
# = you re not that crazy
# < you re not that crazy
#
# > ils sont sortis faire les magasins
# = they are out shopping
# < they are out shopping
#
# > je ne suis pas en service
# = i m off duty
# < i am off duty
#
# > c est celui qui m a tripotee
# = he s the one who touched me
# < he s the one who touched me
#
# > elles sont mauvaises
# = they re bad
# < they re bad bad
#
# > c est maree basse
# = you re out of booze
# < you re out of booze
#
# > je suis plutot heureux
# = i m fairly happy
# < i m rather happy
#
# > tu n es pas notre ami
# = you are not our friend
# < you are not our friend of yours
#
# > je suis celui qui a introduit le sujet
# = i m the one who brought the subject up
# < i m the one who brought the subject up
#
# > nous sommes des gagneurs
# = we re winners
# < we re winners
#
# > tu es avec des amis
# = you re with friends
# < you re with friends
#
# > vous etes une vraie loque
# = you re a total wreck
# < you re a total wreck
#
# > je suis surpris de te voir
# = i m surprised to see you
# < i m surprised to see you
#
# > vous n etes pas les seules avec ce probleme
# = you re not the only one with this problem
# < you re not the only one with this problem
#
# > nous sommes confrontes a une foule de problemes
# = we are faced with a host of problems
# < we are faced with a host of problems
#
# > je suis tres triste
# = i am very sad
# < i m very sad
#
# > je suis horrible avec les gamins
# = i m horrible with kids
# < i m horrible with kids
#
# > tu te plains toujours
# = you are always complaining
# < you re always complaining always always complaining
#
# > je suis ravie de t aider
# = i am glad to help you
# < i am glad to help you
#
# > nous nous en approchons
# = we re getting close
# < we re getting close about right
#
# > nous sommes a court de balles
# = we re out of bullets
# < we re out of bullets
#
# > vous passez a cote
# = you re missing the point
# < you re missing the wrong point
#
# > je suis trop fatigue pour marcher davantage
# = i am too tired to walk any more
# < i am too tired to walk any more
#
# > il est casse couilles avec moi
# = he is giving me a hard time
# < he is giving me a hard time
#
# > je ne suis pas encore mort
# = i m not dead yet
# < i m not dead yet
#
# > vous etes la seule desormais pour moi
# = you re the only one for me now
# < you re the only one for me now
#
# > je vois mary cette apres midi
# = i am seeing mary this afternoon
# < i am seeing mary this afternoon
#
# > je suis disponible
# = i m free
# < i m free of
#
# > ils sont a l exterieur
# = they re outside
# < they re outside
#
# > elle est une mere tres avisee
# = she s a very wise mother
# < she s a very wise mother
#
# > je suis incontrolable
# = i m out of control
# < i m out of control
#
# > j ai un peu faim
# = i m a bit hungry
# < i m a little hungry
#
# > ce sont tous les miens
# = they re all mine
# < they re all mine
#
# > elle a la peau noire
# = she is dark skinned
# < she is dark skinned
#
# > je ne suis pas sourd
# = i am not deaf
# < i m not deaf
#
# > je suis fier de mes enfants
# = i m proud of my children
# < i m proud of my children
#
# > je suis touche !
# = i m hit !
# < i m hit !
#
# > je suis effondre d entendre ca
# = i m very sorry to hear that
# < i m very sorry to hear that
#
# > je suis surpris que ca ait ete si facile
# = i m surprised it was that easy
# < i m surprised it was that easy
#
# > c est vous l ainee
# = you re the oldest
# < you re the oldest
#
# > tu es probablement fatiguee
# = you re probably tired
# < you re probably tired
#
# > je crains que vous n ayez le mauvais numero
# = i m afraid you have the wrong number
# < i m afraid you have the wrong number
#
# > je n en suis plus sur
# = i m not sure anymore
# < i m not sure anymore
#
# > tu n y es pas bon
# = you re not good at this
# < you re not good at this
#
# > je suis en pause dejeuner
# = i m on my lunch break
# < i m on my lunch break
#
# > tu dramatises
# = you re overreacting
# < you re overreacting
#
# > je suis heureux de te voir
# = i m glad to see you
# < i m glad to see you
#
# > je veux aller faire des courses
# = i m going to do some shopping
# < i m going to do some shopping
#
# > j ai les chocottes
# = i m chicken
# < i m chicken
#
# > je suis en train de developper une application android
# = i m developing an android application
# < i m developing an android application
#
# > je n en ai pas encore termine
# = i m not finished yet
# < i m not finished yet
#
# > vous etes bavards
# = you re talkative
# < you re talkative
#
# > vous etes acariatre
# = you re cantankerous
# < you re cantankerous
#
# > nous nous en occupons
# = we re dealing with it
# < we re dealing with it
#
# > il nettoie sa carabine
# = he s cleaning his rifle
# < he s cleaning his rifle
#
# > je n en suis pas fier
# = i m not proud of it
# < i m not proud of it
#
# > il est tres ouvert
# = he s very open
# < he s very open open
#
# > je n y excelle pas
# = i m not very good at it
# < i m not very good at it
#
# > j essaye de sauver la vie de tom
# = i m trying to save tom s life
# < i m trying to save tom s life
#
# > tu es merveilleuse
# = you re wonderful
# < you re wonderful
#
# > il n est pas vraiment l impresario
# = he isn t actually the manager
# < he isn t actually the manager
#
# > vous etes en avance
# = you are early
# < you are early
#
# > vous etes bonne
# = you re good
# < you re good
#
# > je suis satisfait de leur performance
# = i m pleased with their performance
# < i m pleased with their performance
#
# > tu es tres vif
# = you re very sharp
# < you re very sharp
#
# > je suis a present dans un vieux chateau
# = i am now in an old castle
# < i am now in an old castle
#
# > je suis votre et vous etes mien
# = i am yours and you are mine
# < i am yours and you are mine
#
# > je suis ami avec la s ur de tom
# = i m friends with tom s sister
# < i m friends with tom s sister
#
# > je ne vais te le montrer qu une fois
# = i m only going to show you once
# < i m only going to show you once
#
# > elles ne sont pas mauvaises
# = they re not evil
# < they re not evil
#
# > nous nous rendons au cinema
# = we re going to the movies
# < we re going to the movies
#
# > nous sommes en guerre
# = we re at war
# < we are at war at war
#
# > c est un pleurnichard comme toujours
# = he s a crybaby just like always
# < he s a crybaby just like always as ever
#
# > je le fais pour elles
# = i m doing this for them
# < i m doing this for them
#
# > il n est pas tel qu il parait
# = he is not like he seems
# < he is not like he seems
#
# > il n est pas un saint
# = he s no saint
# < he s no saint
#
# > nous n allons pas vous repondre
# = we re not going to do it
# < we re not going to do it
#
# > je ne suis pas parfaite
# = i m not perfect
# < i m not perfect
#
# > il est dj
# = he is a dj
# < he s a dj
#
# > elle est au regime
# = she is dieting
# < she is on a diet
#
# ...
# = i m dissatisfied
# < i m not satisfied
#
# > j en suis heureux
# = i m happy with it
# < i m happy with it s happy
#
# > elle est extremement seduisante
# = she is extremely attractive
# < she is extremely attractive beautiful
#
# > c est mon frere pas mon pere
# = he is my brother not father
# < he is my brother not father
#
# > c est un de ces pauvres types !
# = he s such a jerk
# < he s such a jerk
#
# > vous etes toutes seules
# = you re all alone
# < you re all alone
#
# > tu reagis de maniere excessive
# = you re overreacting
# < you re overreacting
#
# > je ne suis pas si preoccupe
# = i m not that worried
# < i m not that worried
#
# > il est trop lent
# = he s too slow
# < he s too slow slow close
#
# > je suis en chemin pour mon travail
# = i m on my way to work
# < i m on my way to work
#
# > vous allez gagner aujourd hui
# = you re going to win today
# < you re going to win today
#
# > je suis bon en ski
# = i m good at skiing
# < i m good at skiing
#
# > il est apres moi
# = he s after me
# < he s after me
#
# > je prends des vacances
# = i m taking a vacation
# < i m taking a vacation next vacation
#
# > je suis le plus jeune enfant
# = i m the youngest child
# < i m the youngest in the family
#
# > je suis plus beau que tom
# = i m better looking than tom
# < i m better looking than tom
#
# > tu es mignonne dans ton genre
# = you re kind of cute
# < you re kind of cute
#
# > j en suis mecontent
# = i m not happy with this
# < i m not happy with this
#
# > j essaie simplement de survivre
# = i m just trying to survive
# < i m just trying to survive
#
# > je suis ravi d etre ici
# = i am delighted to be here
# < i m glad i could be here
#
# > je ne suis pas medecin mais professeur
# = i am not a doctor but a teacher
# < i am not a doctor but a teacher
#
# > c est la fille de mes reves
# = she s the girl of my dreams
# < she s the girl of my dreams
#
# > vous etes le seul a pouvoir m aider
# = you re the only one who can help me
# < you re the only one who can help me
#
# > il est joueur
# = he s a gambler
# < he s a gambler
#
# > je verrai mon oncle demain
# = i am seeing my uncle tomorrow
# < i am seeing my uncle tomorrow
#
# > nous achetons des billets de cinema
# = we re buying movie tickets
# < we re buying movie tickets
#
# > je suis endurant
# = i m resilient
# < i m resilient
#
# > c est ma copine
# = she is my girlfriend
# < she is my girlfriend s right now
#
# > ce n est pas une beaute
# = she is no beauty
# < she is no beauty
#
# > tu es matinale
# = you are early
# < you re early
#
# > je vais etudier le francais l annee prochaine
# = i m going to study french next year
# < i m going to study french next year
#
# > vous n etes pas l unique femme ici
# = you re not the only woman here
# < you re not the only woman here
#
# > on te regarde
# = you re being watched
# < you re wanted
#
# > vous n etes pas le bienvenu ici
# = you re not welcome here
# < you re not welcome here
#
# > je passe la nuit chez mon ami
# = i m staying over at my friend s place
# < i m staying over at my friend s place at
#
# > nous ne sommes pas en train de nous repentir
# = we re not trying to make amends
# < we re not trying to make amends
#
# > vous etes celle qui m a forme
# = you re the one who trained me
# < you re the one who trained me
#
# > elle vit au milieu de nulle part
# = she is living in the middle of nowhere
# < she is living in the middle of nowhere
#
# > c est une bombe
# = she s a hottie
# < she s a hottie
#
# > il est impatient de te voir
# = he is impatient to see you
# < he is impatient to see you
#
# > tu es deloyale
# = you re disloyal
# < you re disloyal
#
# > vous n etes pas cense etre la dedans
# = you re not supposed to be in here
# < you re not supposed to be in here
#
# > je suis la seule qui peut faire cela
# = i m the only one who can do that
# < i m the only one who can do that
#
# > il est toujours en retard a l ecole
# = he is always late for school
# < he s always late for school
#
# > il a honte de son attitude
# = he is ashamed of his behavior
# < he is ashamed of his behavior
#
# > tu es tres gentil
# = you re very nice
# < you re very nice
#
# > je suis desole de vous avoir derangee !
# = i m sorry to have bothered you
# < i m sorry to have bothered you
#
# > elles ne sont pas mauvaises
# = they re not evil
# < they re not evil
#
# > je suis ton partenaire
# = i m your partner
# < i m your partner
#
# > je suis celibataire
# = i m single
# < i m single
#
# > il est soul
# = he is drunk
# < he is drunk
#
# > je vais envoyer de l argent a tom
# = i m going to send tom some money
# < i m going to send tom some money
#
# > tu agis comme un enfant
# = you re acting like a child
# < you re acting like a child
#
# > je ne suis pas un voleur
# = i m not a thief
# < i m not a thief
#
# > je ne vais pas bien du tout
# = i am not well at all
# < i am not well at all
#
# > vous avez tort dans ce cas
# = you re wrong in this case
# < you re wrong in this case
#
# > il est tres impatient d y aller
# = he is very eager to go there
# < he is very eager to go there
#
# > je vais sortir
# = i m about to go out
# < i m going to do something else
#
# > tu tires avantage de sa faiblesse
# = you re taking advantage of her weakness
# < you re taking advantage of her weakness
#
# > vous etes ruse
# = you re crafty
# < you re crafty
#
# > je suis vraiment tres fatigue aujourd hui
# = i m really tired today
# < i m really tired today
#
# > je suis un tel idiot
# = i m such a fool
# < i m such a fool man
#
# > je ne suis pas joueuse
# = i m not a gambler
# < i m not a gambler
#
# > tu gaspilles des munitions
# = you re wasting ammo
# < you re wasting ammo
#
# > je suis simplement franc
# = i m just being honest
# < i m just being honest
#
# > je suis satisfaite de sa representation
# = i m pleased with his performance
# < i m pleased with his performance
#
# > je suis tout a fait pret
# = i m all set
# < i m all set
#
# > je suis fortunee
# = i m wealthy
# < i m wealthy
#
# > il est tres contrarie par cela
# = he s very upset by this
# < he s very upset by this
#
# > c est une beaute
# = she is a beauty
# < she is a beauty
#
# > j ai raison
# = i m right
# < i m right
#
# > vous etes plus grands qu elle
# = you are taller than she is
# < you are taller than she is
#
# > tu vas devoir arreter de faire ca
# = you re going to have to stop doing that
# < you re going to have to stop doing that
#
# > elles sont toutes tres heureuses
# = they are all very happy
# < you re all very happy to be
#
# > il est grand et mince
# = he s tall and slim
# < he s tall and slim and slim
#
# > tu es mon heros
# = you are my hero
# < you are my hero
#
# > il est assez sauvage
# = he is quite a savage
# < he is quite a savage savage
#
# > tu es matinale
# = you are early
# < you re early
#
# > j ai hate de te voir bientot
# = i m looking forward to seeing you soon
# < i m looking forward to seeing you soon
#
# > je compte sur ton aide
# = i m counting on your help
# < i am counting on your help after your help
#
# > elle a honte de s exprimer
# = she is ashamed to speak up
# < she is ashamed to speak up
#
# > je suis desolee de vous avoir tire dessus
# = i m sorry i shot you
# < i m sorry i shot you
#
# > ils sont vraiment serres
# = they re really tight
# < they re really tight
#
# > je suis desole ce vol est plein
# = i m sorry the flight is full
# < i m sorry the flight is full
#
# > vous etes mon heroine
# = you are my hero
# < you are my hero
#
# > il est la pour quelques jours
# = he is there for a few days
# < he is there for a few days
#
# > il est capitaine de l equipe de football
# = he is captain of the football team
# < he is captain of the football team
#
# > elle est toujours a fumer
# = she is always smoking
# < she is always smoking to know him
#
# > je suis chez une amie
# = i m at a friend s house
# < i m at a friend s house
#
# > tu es trop faible
# = you re too weak
# < you re too weak
#
# > il se cache dans la penderie
# = he s hiding in the closet
# < he s hiding in the closet at down
#
# > vous n etes pas tom
# = you aren t tom
# < you aren t tom
#
# > je ne vais pas bien
# = i m not well
# < i m not well well
#
# > je ne suis pas perfectionniste
# = i m not a perfectionist
# < i m not a perfectionist
#
# > ils sont partis
# = they re gone
# < they re gone
#
# > tu es faible
# = you re weak
# < you re weak
#
# > sans toi je suis triste
# = i m sad without you
# < i m sad without you
#
# > je suis un tel idiot
# = i m such an idiot
# < i m such a fool man
#
# > nous sommes tellement contentes de vous avoir ici !
# = we re so glad to have you here
# < we re so glad to have you here
#
# > ils parlent de musique
# = they are talking about music
# < they are talking about music
#
# > vous etes en train de gaspiller mon temps
# = you re wasting my time
# < you re wasting my time
#
# > il trouve toujours a redire aux autres
# = he is always finding fault with other people
# < he is always finding fault with others
#
# > j en suis vraiment fier
# = i m really proud of it
# < i m really proud of this
#
# > vous etes la de bonne heure ce matin !
# = you are very early this morning
# < you are very early this morning
#
# > j attends de toi un travail serieux
# = i am expecting some serious work from you
# < i am expecting some serious work from you
#
# > il est tres courageux
# = he is very brave
# < he s very religious brave
#
# > je ne suis toujours pas impressionnee
# = i m still not impressed
# < i m still not impressed impressed
#
# > nous retournons en arriere
# = we re turning back
# < we re turning back
#
# > tu n aides pas tom
# = you re not helping tom
# < you re not helping tom
#
# > je suis desolee je ne vous reconnais pas
# = i m sorry i don t recognize you
# < i m sorry i don t recognize you
#
# > j ai raison
# = i m correct
# < i m right
#
# > ils sont trop gros
# = they re too fat
# < they re too fat
#
# > je suis toujours heureuse
# = i m always happy
# < i m still happy
#
# > je n appartiens pas a ce monde
# = i m not from this world
# < i m not from this world
#
# > je vais ecrire une lettre
# = i am going to write a letter
# < i am going to write a letter
#
# > vous n etes pas censees nager ici
# = you aren t supposed to swim here
# < you aren t supposed to swim here
#
# > elle est bonne en ski
# = she is good at skiing
# < she is good at skiing
#
# > j ai soif
# = i am thirsty
# < i m thirsty
#
# > je n ai plus sommeil
# = i m no longer sleepy
# < i m no longer sleepy
#
# > tu as trois heures de retard
# = you re three hours late
# < you re three hours late
#
# > vous en avez fini
# = you re through
# < you re through
#
# > il est trop occupe
# = he s too busy
# < he s too busy
#
# > je ne suis pas comme ca
# = i m not like that
# < i m not like that
#
# > vous etes vraiment magnifique
# = you re really gorgeous
# < you re really gorgeous
#
# > vous n etes pas un medecin
# = you are not a doctor
# < you are not a doctor but a doctor
#
# > je fais frire du poisson
# = i am frying fish
# < i am frying fish
#
# > j ai peur qu il ne commette une erreur
# = i am afraid he will make a mistake
# < i am afraid he will make a mistake
#
# > j ai faim !
# = i m hungry
# < i m hungry
#
# > il y joue
# = he is playing there
# < he is playing there
#
# > je taquine
# = i m teasing
# < i m teasing
#
# > je vais en faire usage demain
# = i m going to use it tomorrow
# < i m going to use it tomorrow
#
# > je ne suis sure de rien
# = i m not sure of anything
# < i m not sure of anything
#
# > je suis desole de vous avoir hurle dessus
# = i m sorry i yelled at you
# < i m sorry i yelled at you
#
# > nous sommes des gagneurs
# = we re winners
# < we re winners
#
# > je suis sure que tout ira bien
# = i m sure everything will be fine
# < i m sure everything will be ok
#
# > il est vraiment sans c ur
# = he is so heartless
# < he is so heartless
#
# > il est tres amical avec nous
# = he is very friendly to us
# < he is very friendly to us
#
# > ils ne sont pas encore a la maison
# = they re not home yet
# < they re not home yet
#
# > vous etes deloyaux
# = you re disloyal
# < you re disloyal
#
# > je ne suis pas fatigue du tout
# = i m not at all tired
# < i m not at all tired
#
# > je pense apprendre le coreen le semestre prochain
# = i m thinking of learning korean next semester
# < i m thinking of learning korean next semester
#
# > c est un de mes meilleurs amis
# = he is one of my best friends
# < he is one of my best friends
#
# > elle est une personne tres interessante
# = she s a very interesting person
# < she s a very interesting person
#
# > je crains l examen
# = i m dreading the exam
# < i m afraid the same exam
#
# > c est une fille tres gentille
# = she s a very nice girl
# < she s a very nice girl
#
# > je ne suis pas bon la dedans
# = i m not good at this
# < i m not good at this
#
# > il est borne
# = he is thick headed
# < he is thick headed
#
# > vous etes grands
# = you re big
# < you are big
#
# > vous n etes pas autorisee a manger ceux ci
# = you re not allowed to eat those
# < you re not allowed to eat those
#
# > elle est en train d arroser les fleurs
# = she is watering the flowers
# < she is watering the flowers
#
# > c est l un des meilleurs
# = he s one of the best
# < he s one of the best best
#
# > elles sont en colere apres vous
# = they re mad at you
# < they re mad at you
#
# > nous ne sommes pas partenaires
# = we re not partners
# < we re not partners
#
# > je ne suis pas sur de comprendre
# = i m not sure i understand
# < i m not sure i understand
#
# > tu es veinarde
# = you re in luck
# < you re in big
#
# > je suis content que la pluie se soit arretee
# = i m glad that the rain has stopped
# < i m glad that the rain has stopped
#
# > je suis vanne
# = i m exhausted
# < i m exhausted
#
# > nous sommes seuls
# = we re alone
# < we re alone
#
# > tu es le seul en qui j ai confiance
# = you re the only one i trust
# < you re the only one i trust
#
# > il n est pas japonais
# = he is not japanese
# < he is not japanese
#
# > il maitrise la nouvelle technique
# = he s got the new technique down pat
# < he s got the new technique down pat
#
# > je n en suis pas si convaincu
# = i m not so convinced
# < i m not so convinced
#
# > tu es le chef
# = you re the leader
# < you re the leader
#
# > tu es bonne cuisiniere n est ce pas ?
# = you are a good cook aren t you ?
# < you are a good cook aren t you ?
#
# > elle est encore jeune
# = she s still young
# < she s still young woman
#
# > je vais le regretter
# = i m going to regret this
# < i m going to regret this
#
# > vous etes fort grossiers
# = you re very rude
# < you re very rude
#
# > je suis certain
# = i am sure
# < i m sure i am
#
# > je ne suis pas sure d etre d accord
# = i m not sure i agree
# < i m not sure i agree
#
# > je pense partir a l etranger l annee prochaine
# = i am thinking of going abroad next year
# < i am thinking of going abroad next year
#
# > elle est privee de sortie
# = she is forbidden to go out
# < she is forbidden to go out
#
# > je commence a me sentir deja mieux
# = i m starting to feel better already
# < i m starting to feel better already
#
# > je ne suis qu un simple employe de bureau
# = i m just a plain old office worker
# < i m just a plain old office worker
#
# > j essaie de vous parler
# = i m trying to talk to you
# < i m trying to talk to you
#
# > je suis trop somnolent pour conduire
# = i m too sleepy to drive
# < i m too sleepy to drive
#
# > je suis rarement autant en colere
# = i m rarely this angry
# < i m rarely this angry
#
# > c est un garcon tres chouette
# = he s a very nice boy
# < he s a very nice boy boy
#
# > elle n est pas toujours heureuse
# = she is not always happy
# < she is not always happy yet
#
# > je suis repu !
# = i m full
# < i m full
#
# > nous en avons completement fini
# = we re all done
# < we re all done
#
# > il lui fait du chantage
# = she is being blackmailed by him
# < she is being blackmailed by him
#
# > je suis juste un monsieur tout le monde
# = i am just a nobody
# < i am just a nobody
#
# > vous etes fort grossier
# = you re very rude
# < you re very rude
#
# > je suis responsable des courses
# = i m in charge of shopping
# < i m in charge of shopping
#
# > il est en colere apres tout le monde
# = he s mad at everyone
# < he s mad at everyone
#
# > il fait du velo
# = he is riding a bicycle
# < he is riding a bicycle
#
# > vous etes fort serviables
# = you re very helpful
# < you re very helpful
#
# > nous sommes enseignantes
# = we are teachers
# < we are teachers
#
# > il part pour new york la semaine prochaine
# = he is leaving for new york next week
# < he is leaving for new york next week
#
# > je suis introvertie
# = i m introverted
# < i m introverted
#
# > ils sont juste derriere toi
# = they re right behind you
# < they re right behind you
#
# > tu es snob
# = you re a snob
# < you re a snob
#
# > je porte des lunettes de soleil
# = i m wearing sunglasses
# < i m wearing sunglasses
#
# > j envisage de rester chez lui demain
# = i m planning on staying at his place tomorrow
# < i m planning on staying at his place tomorrow
#
# > il etudie tout le temps
# = he is always studying
# < he is always studying now
#
# > tu es le seul canadien que je connaisse
# = you re the only canadian i know
# < you re the only canadian i know
#
# Accuracy: 77.65%

# %% [markdown]
# Visualizing Attention
# =====================
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run `plt.matshow(attentions)` to see attention output
# displayed as a matrix. For a better viewing experience we will do the
# extra work of adding axes and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.cpu().numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))


    # save the plot with a filename that includes the input sentence 
    plt.savefig('%s.png' % input_sentence.replace(' ', '_'))
    plt.close()

def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(encoder, decoder, input_sentence, input_lang, output_lang)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions[0, :len(output_words), :])
# Out:
# input = il n est pas aussi grand que son pere
# output = he is not as tall as his father <EOS>
# /tmp/ipykernel_32561/96750365.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_32561/96750365.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + output_words)
# input = je suis trop fatigue pour conduire
# output = i m too tired to drive <EOS>
# /tmp/ipykernel_32561/96750365.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_32561/96750365.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + output_words)
# /tmp/ipykernel_32561/96750365.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_32561/96750365.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + output_words)
# input = je suis desole si c est une question idiote
# output = i m sorry if this is a stupid question <EOS>
# input = je suis reellement fiere de vous
# output = i m really proud of you <EOS>
# /tmp/ipykernel_32561/96750365.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_32561/96750365.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + output_words)

# %%
evaluateAndShowAttention('je vais a l ecole en bus')
# Out:
# input = je vais a l ecole en bus
# output = i am going to college <EOS>
# /tmp/ipykernel_32561/96750365.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# /tmp/ipykernel_32561/96750365.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + output_words)
